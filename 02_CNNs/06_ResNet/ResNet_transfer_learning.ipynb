# %% [markdown]
# # 1. Import und Hardware Setup

# %% [markdown]
# # 2. Hyperparameters

# %% [markdown]
# # 3. Data Preparation

# %% [markdown]
# # 4. Pre-trained Model

# %% [markdown]
# # 5. Training Preparation

# %% [markdown]
# # 6. Train

# %% [markdown]
# # 7. GradCAM
