# %% [markdown]
# # 1. Import and Hardware Setup

# %%
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms

import matplotlib.pyplot as plt
import time
import copy

# !pip install tqdm -q
from tqdm.auto import tqdm

# !pip install wandb -q
import wandb

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
DATA_PATH = './Data'
SAVE_PATH = './Model'

# %%
# Login Weight & Bias
wandb.login()
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /teamspace/studios/this_studio/.netrc.
# wandb: Currently logged in as: blendezu (blendezu-th-k-ln) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# # 2. Hyperparameters

# %%
BATCH_SIZE = 32
IMG_SIZE = 227
IMG_CHANNELS = 3
NUM_CLASSES = 101

EPOCHS = 300
LR = 0.01
DROPOUT_RATE = 0.5

# %% [markdown]
# # 3. Dataset Preparation

# %%
stats = ((0.545, 0.443, 0.344), (0.269, 0.271, 0.276))

train_transform = transforms.Compose([
    transforms.Resize(256),
    transforms.RandomResizedCrop(227),
    transforms.AutoAugment(transforms.AutoAugmentPolicy.IMAGENET),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(*stats)
])

test_transform = transforms.Compose([
    transforms.Resize((227, 227)),
    transforms.ToTensor(),
    transforms.Normalize(*stats)
])

# %%
# Load the full train data
full_train_data = datasets.Food101(root=DATA_PATH, download=True, split='train', transform=train_transform)

# Split the full train data into train and validation data
train_size = int(0.8 * len(full_train_data))
val_size = len(full_train_data) - train_size

train_subset, val_subset = random_split(full_train_data, (train_size, val_size))

# Change transform von val_subset to test_transform
val_subset.dataset = copy.copy(full_train_data)
val_subset.dataset.transform = test_transform

# Load Test Dataset
test_dataset = datasets.Food101(root=DATA_PATH, download=True, split='test', transform=test_transform)

# %%
# Loader
train_loader = DataLoader(train_subset, batch_size=BATCH_SIZE, shuffle=True,
                        num_workers=4, pin_memory=True, persistent_workers=True)

val_loader = DataLoader(val_subset, batch_size=BATCH_SIZE, shuffle=True,
                        num_workers=4, pin_memory=True, persistent_workers=True)

test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True,
                        num_workers=4, pin_memory=True, persistent_workers=True)

# %% [markdown]
# # 4. AlexNet Architecture
#
# ![AlexNet](AlexNet.png)

# %%
class AlexNet(nn.Module):
    def __init__(self, img_size, in_channels, num_classes, dropout_rate):
        super().__init__()
        self.feature_extractor = nn.Sequential(
            # Conv 1: 227x227 -> 55x55
            nn.Conv2d(in_channels, 96, kernel_size=11, stride=4),
            nn.ReLU(inplace=True),
            nn.LocalResponseNorm(size=5, alpha=0.0001, beta=0.75, k=2),

            # MaxPool 1: 55x55 -> 27x27
            nn.MaxPool2d(kernel_size=3, stride=2),

            # Conv 2: 27x27 -> 27x27
            nn.Conv2d(96, 256, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.LocalResponseNorm(size=5, alpha=0.0001, beta=0.75, k=2),

            # MaxPool 2: 27x27 -> 13x13
            nn.MaxPool2d(kernel_size=3, stride=2),

            # Conv 3: 13x13 -> 13x13
            nn.Conv2d(256, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),

            # Conv 4: 13x13 -> 13x13
            nn.Conv2d(384, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),

            # Conv 5: 13x13 -> 13x13
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),

            # MaxPool 3: 13x13 -> 6x6
            nn.MaxPool2d(kernel_size=3, stride=2)
        )

        self.classifier = nn.Sequential(
            nn.Dropout(dropout_rate),
            nn.Linear(9216, 4096), #  6x6x256 = 9216 -> 4096
            nn.ReLU(inplace=True),

            nn.Dropout(dropout_rate),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),

            nn.Linear(4096, num_classes)
        )

    def forward(self, x):
        x = self.feature_extractor(x)
        x = torch.flatten(x, 1)
        logits = self.classifier(x)

        return logits

model = AlexNet(IMG_SIZE, IMG_CHANNELS, NUM_CLASSES, DROPOUT_RATE).to(device)

# %% [markdown]
# # 5. Training

# %%
import numpy as np

class EarlyStopping:
    """ Early stops the training if validation loss doesn't improve after 
        a given patience.
    """
    def __init__(self, patience=5, verbose=False, delta=0, save_path='best_checkpoint.pth', 
                                            trace_func=print):
        self.patience = patience
        self.verbose = verbose
        self.delta = delta
        self.save_path = save_path
        self.trace_func = trace_func
        
        self.counter = 0
        self.best_score = None
        self.val_loss_min = np.inf
        self.early_stop = False

    def __call__(self, val_loss, model):

        # 1. First epoch
        if self.best_score is None:
            self.best_score = val_loss
            self.save_checkpoint(val_loss, model)

        # 2. If the validation loss is larger than the best score
        # -> Increase the counter
        elif val_loss > self.best_score - self.delta:
            self.counter += 1
            self.trace_func(f"EarlyStopping counter: {self.counter} out of {self.patience}")
            if self.counter >= self.patience:
                self.early_stop = True

        # 3. The Validation Loss reduced -> Save the model
        else:
            self.best_score = val_loss
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        if self.verbose:
            self.trace_func(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        self.val_loss_min = val_loss
        torch.save(model.state_dict(), self.save_path)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=LR, momentum=0.9, weight_decay=5e-4)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=5, factor=0.1)

# Using GradScaler to prevent Gradient Underflow when using FP16
scaler = torch.amp.GradScaler(device)

# %%
def train(model, loader, criterion, optimizer, scheduler):
    # Set the model into train mode
    model.train()
    
    # Define the loss and acc
    train_loss, correct = 0, 0

    # Create Loading Progress with
    loop = tqdm(loader, desc="Training", leave=False)

    # Loop through the loop
    for x, y in loop:
        # Move training data to device
        x, y = x.to(device), y.to(device)

        # Clear the gradients of last batch, set to None to save memory
        optimizer.zero_grad(set_to_none=True)

        # 
        with torch.amp.autocast(device_type=device.type):
            # get the prediction
            out = model(x)
            # Calculate loss
            loss = criterion(out, y)

        # Scaling the loss -> Backpropagation
        scaler.scale(loss).backward()
        # scaler.scale(loss): multiplies the loss by a larger "scale factor"
        # -> The loss becomes larger, moving them out of the "underflow zone"
        # .backward(): performs the standard backpropagation

        # Unscale before clipping
        scaler.unscale_(optimizer)
        nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        
        # Unscale the gradients before the optimizer updates the weights
        scaler.step(optimizer)

        # Adjusts the scale factor for the next batch
        scaler.update()

        train_loss += loss.item() * x.size(0)
        correct += (out.argmax(1) == y).sum().item()

    return train_loss / len(loader.dataset), correct / len(loader.dataset)

# %%
def validate(model, loader, criterion):
    model.eval()
    val_loss, val_acc = 0, 0

    loop = tqdm(loader, desc="Validation", leave=False)

    with torch.no_grad():
        for x, y in loop:
            x, y = x.to(device), y.to(device)

            out = model(x)
            loss = criterion(out, y)

            val_loss += loss.item() * x.size(0)
            val_acc += (out.argmax(1) == y).sum().item()

    return val_loss / len(loader.dataset), val_acc / len(loader.dataset)

# %%
def evaluate(model, loader):
    model.eval()
    eval_acc = 0

    loop = tqdm(loader, desc="Testing", leave=False)

    with torch.no_grad():
        for x, y in loop:
            x, y = x.to(device), y.to(device)
            out = model(x)

            eval_acc += (out.argmax(1) == y).sum().item()

    return eval_acc / len(loader.dataset)

# %%
import numpy as np

wandb.init(
    project = "AlexNet",
    config = {
        "Architecture": "AlexNet",
        "epochs": EPOCHS,
        "batch_size": BATCH_SIZE,
        "image_size": IMG_SIZE
    }
)

train_accuracies, test_accuracies = [], []
train_losses, test_losses = [], []
early_stopping = EarlyStopping(patience=3, save_path='AlexNet_best_model.pth')

for epoch in range(EPOCHS):
    train_loss, train_acc = train(model, train_loader, criterion, optimizer, scheduler)
    val_loss, val_acc = validate(model, val_loader, criterion)
    scheduler.step(val_loss)
    
    test_acc = evaluate(model, test_loader)

    train_accuracies.append(train_acc)
    test_accuracies.append(test_acc)
    train_losses.append(train_loss)
    test_losses.append(val_loss)

    wandb.log({
        "epoch": epoch + 1,
        "train_loss": train_loss,
        "val_loss": val_loss,
        "train_acc": train_acc,
        "val_acc": val_acc,
        "test_acc": test_acc,
        "lr": optimizer.param_groups[0]['lr']
    })

    print(f"{epoch+1}/{EPOCHS}: train_loss: {train_loss:.4f}, val_loss: {val_loss:.4f}," +
                             f" train_acc: {train_acc:.4f}, val_acc: {val_acc:.4f}, test_acc: {test_acc:.4f}")

    early_stopping(val_loss, model)

    if early_stopping.early_stop:
        print("Early Stopping")
        break



wandb.finish()
# Out:
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/teamspace/studios/this_studio/DLODT/02_CNNs/02_AlexNet/wandb/run-20260319_072612-8dilejbb</code>
# Syncing run <strong><a href='https://wandb.ai/blendezu-th-k-ln/AlexNet/runs/8dilejbb' target="_blank">apricot-salad-21</a></strong> to <a href='https://wandb.ai/blendezu-th-k-ln/AlexNet' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/blendezu-th-k-ln/AlexNet' target="_blank">https://wandb.ai/blendezu-th-k-ln/AlexNet</a>
#  View run at <a href='https://wandb.ai/blendezu-th-k-ln/AlexNet/runs/8dilejbb' target="_blank">https://wandb.ai/blendezu-th-k-ln/AlexNet/runs/8dilejbb</a>
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 1/300: train_loss: 4.6163, val_loss: 4.6167, train_acc: 0.0095, val_acc: 0.0087, test_acc: 0.0099
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 2/300: train_loss: 4.6056, val_loss: 4.5692, train_acc: 0.0121, val_acc: 0.0176, test_acc: 0.0175
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 3/300: train_loss: 4.5706, val_loss: 4.5252, train_acc: 0.0173, val_acc: 0.0202, test_acc: 0.0230
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 4/300: train_loss: 4.5354, val_loss: 4.4882, train_acc: 0.0203, val_acc: 0.0301, test_acc: 0.0316
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 5/300: train_loss: 4.5093, val_loss: 4.4351, train_acc: 0.0224, val_acc: 0.0255, test_acc: 0.0298
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 6/300: train_loss: 4.4760, val_loss: 4.3310, train_acc: 0.0275, val_acc: 0.0360, test_acc: 0.0402
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 7/300: train_loss: 4.4199, val_loss: 4.2928, train_acc: 0.0321, val_acc: 0.0411, test_acc: 0.0482
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 8/300: train_loss: 4.3695, val_loss: 4.2338, train_acc: 0.0380, val_acc: 0.0541, test_acc: 0.0568
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 9/300: train_loss: 4.3304, val_loss: 4.1278, train_acc: 0.0425, val_acc: 0.0609, test_acc: 0.0731
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 10/300: train_loss: 4.2916, val_loss: 4.1164, train_acc: 0.0472, val_acc: 0.0651, test_acc: 0.0733
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 11/300: train_loss: 4.2681, val_loss: 4.0406, train_acc: 0.0511, val_acc: 0.0764, test_acc: 0.0878
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 12/300: train_loss: 4.2469, val_loss: 4.1015, train_acc: 0.0550, val_acc: 0.0678, test_acc: 0.0741
# EarlyStopping counter: 1 out of 3
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 13/300: train_loss: 4.2143, val_loss: 4.0121, train_acc: 0.0613, val_acc: 0.0801, test_acc: 0.0859
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 14/300: train_loss: 4.1884, val_loss: 3.9980, train_acc: 0.0632, val_acc: 0.0877, test_acc: 0.0912
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 15/300: train_loss: 4.1618, val_loss: 3.9669, train_acc: 0.0686, val_acc: 0.0857, test_acc: 0.0882
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 16/300: train_loss: 4.1373, val_loss: 3.9043, train_acc: 0.0720, val_acc: 0.0975, test_acc: 0.1093
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 17/300: train_loss: 4.1098, val_loss: 3.8998, train_acc: 0.0751, val_acc: 0.1063, test_acc: 0.1153
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 18/300: train_loss: 4.0775, val_loss: 3.7835, train_acc: 0.0810, val_acc: 0.1165, test_acc: 0.1239
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 19/300: train_loss: 4.0494, val_loss: 3.7624, train_acc: 0.0845, val_acc: 0.1250, test_acc: 0.1355
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 20/300: train_loss: 4.0245, val_loss: 3.6829, train_acc: 0.0903, val_acc: 0.1388, test_acc: 0.1485
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 21/300: train_loss: 4.0001, val_loss: 3.6958, train_acc: 0.0942, val_acc: 0.1325, test_acc: 0.1469
# EarlyStopping counter: 1 out of 3
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 22/300: train_loss: 3.9700, val_loss: 3.6402, train_acc: 0.0972, val_acc: 0.1486, test_acc: 0.1589
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 23/300: train_loss: 3.9576, val_loss: 3.6538, train_acc: 0.1013, val_acc: 0.1488, test_acc: 0.1604
# EarlyStopping counter: 1 out of 3
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 24/300: train_loss: 3.9396, val_loss: 3.6041, train_acc: 0.1040, val_acc: 0.1537, test_acc: 0.1636
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 25/300: train_loss: 3.9228, val_loss: 3.6079, train_acc: 0.1056, val_acc: 0.1486, test_acc: 0.1642
# EarlyStopping counter: 1 out of 3
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 26/300: train_loss: 3.9112, val_loss: 3.6312, train_acc: 0.1089, val_acc: 0.1486, test_acc: 0.1602
# EarlyStopping counter: 2 out of 3
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 27/300: train_loss: 3.8894, val_loss: 3.5393, train_acc: 0.1115, val_acc: 0.1620, test_acc: 0.1773
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 28/300: train_loss: 3.8763, val_loss: 3.5487, train_acc: 0.1144, val_acc: 0.1526, test_acc: 0.1682
# EarlyStopping counter: 1 out of 3
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 29/300: train_loss: 3.8605, val_loss: 3.5234, train_acc: 0.1162, val_acc: 0.1657, test_acc: 0.1842
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 30/300: train_loss: 3.8544, val_loss: 3.5510, train_acc: 0.1175, val_acc: 0.1610, test_acc: 0.1749
# EarlyStopping counter: 1 out of 3
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 31/300: train_loss: 3.8412, val_loss: 3.4662, train_acc: 0.1205, val_acc: 0.1762, test_acc: 0.1941
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 32/300: train_loss: 3.8305, val_loss: 3.5036, train_acc: 0.1198, val_acc: 0.1686, test_acc: 0.1797
# EarlyStopping counter: 1 out of 3
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 33/300: train_loss: 3.8134, val_loss: 3.4496, train_acc: 0.1249, val_acc: 0.1864, test_acc: 0.2037
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 34/300: train_loss: 3.8038, val_loss: 3.4515, train_acc: 0.1251, val_acc: 0.1850, test_acc: 0.2010
# EarlyStopping counter: 1 out of 3
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 35/300: train_loss: 3.7869, val_loss: 3.4213, train_acc: 0.1284, val_acc: 0.1911, test_acc: 0.2051
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 36/300: train_loss: 3.7794, val_loss: 3.4294, train_acc: 0.1305, val_acc: 0.1855, test_acc: 0.1970
# EarlyStopping counter: 1 out of 3
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 37/300: train_loss: 3.7724, val_loss: 3.3990, train_acc: 0.1322, val_acc: 0.1846, test_acc: 0.2064
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 38/300: train_loss: 3.7612, val_loss: 3.4098, train_acc: 0.1361, val_acc: 0.1892, test_acc: 0.2088
# EarlyStopping counter: 1 out of 3
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 39/300: train_loss: 3.7521, val_loss: 3.3466, train_acc: 0.1366, val_acc: 0.2003, test_acc: 0.2180
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 40/300: train_loss: 3.7381, val_loss: 3.3128, train_acc: 0.1377, val_acc: 0.2103, test_acc: 0.2248
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 41/300: train_loss: 3.7287, val_loss: 3.4756, train_acc: 0.1381, val_acc: 0.1801, test_acc: 0.1989
# EarlyStopping counter: 1 out of 3
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 42/300: train_loss: 3.7300, val_loss: 3.3198, train_acc: 0.1401, val_acc: 0.2074, test_acc: 0.2244
# EarlyStopping counter: 2 out of 3
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 43/300: train_loss: 3.7115, val_loss: 3.3099, train_acc: 0.1431, val_acc: 0.2099, test_acc: 0.2274
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 44/300: train_loss: 3.6983, val_loss: 3.2849, train_acc: 0.1473, val_acc: 0.2151, test_acc: 0.2345
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 45/300: train_loss: 3.6934, val_loss: 3.4009, train_acc: 0.1459, val_acc: 0.1942, test_acc: 0.2142
# EarlyStopping counter: 1 out of 3
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 46/300: train_loss: 3.6825, val_loss: 3.3472, train_acc: 0.1484, val_acc: 0.2042, test_acc: 0.2225
# EarlyStopping counter: 2 out of 3
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 47/300: train_loss: 3.6746, val_loss: 3.2402, train_acc: 0.1496, val_acc: 0.2214, test_acc: 0.2357
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 48/300: train_loss: 3.6714, val_loss: 3.4140, train_acc: 0.1517, val_acc: 0.1898, test_acc: 0.2134
# EarlyStopping counter: 1 out of 3
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 49/300: train_loss: 3.6663, val_loss: 3.4024, train_acc: 0.1530, val_acc: 0.1892, test_acc: 0.2080
# EarlyStopping counter: 2 out of 3
# Training:   0%|          | 0/1894 [00:00<?, ?it/s]
# Validation:   0%|          | 0/474 [00:00<?, ?it/s]
# Testing:   0%|          | 0/790 [00:00<?, ?it/s]
# 50/300: train_loss: 3.6462, val_loss: 3.2747, train_acc: 0.1544, val_acc: 0.2159, test_acc: 0.2371
# EarlyStopping counter: 3 out of 3
# Early Stopping
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>lr</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>test_acc</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▃▄▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇█▇██▇██▇█</td></tr><tr><td>train_acc</td><td>▁▁▁▂▂▂▂▃▃▃▄▄▄▄▄▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇█████</td></tr><tr><td>train_loss</td><td>███▇▇▇▆▆▆▅▅▅▅▅▄▄▄▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▁▁▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▆▆▆▆▆▆▆▇▆▇▇▇▇▇█▇██▇█▇█</td></tr><tr><td>val_loss</td><td>███▇▇▆▆▆▅▅▅▅▅▄▄▄▃▃▃▃▃▃▂▃▂▂▂▂▂▂▂▁▂▁▁▂▂▁▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>50</td></tr><tr><td>lr</td><td>0.01</td></tr><tr><td>test_acc</td><td>0.23711</td></tr><tr><td>train_acc</td><td>0.15437</td></tr><tr><td>train_loss</td><td>3.64622</td></tr><tr><td>val_acc</td><td>0.21591</td></tr><tr><td>val_loss</td><td>3.27474</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">apricot-salad-21</strong> at: <a href='https://wandb.ai/blendezu-th-k-ln/AlexNet/runs/8dilejbb' target="_blank">https://wandb.ai/blendezu-th-k-ln/AlexNet/runs/8dilejbb</a><br> View project at: <a href='https://wandb.ai/blendezu-th-k-ln/AlexNet' target="_blank">https://wandb.ai/blendezu-th-k-ln/AlexNet</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260319_072612-8dilejbb/logs</code>

# %% [markdown]
# # 6. Result Plot

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(test_losses, label='Test Loss')
plt.title('Loss History')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Accuracy History')
plt.legend()

# %% [markdown]
# # 7. Heatmap with Grad-CAM

# %%
# !pip install grad-cam -q
import torchvision.transforms.functional as F_vision
from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.image import show_cam_on_image
import random

# 1. Setup the Grad-CAM object
# AlexNet's last conv layer is the 3. to last element in the
# feature_extractor (followed by ReLU and MaxPool)
target_layers = [model.feature_extractor[-3]]
cam = GradCAM(model=model, target_layers=target_layers)

# 2. Pick a random image from the test set
imgs, labels = next(iter(test_loader))
indx = random.randint(0, len(imgs) - 1)
input_tensor = imgs[indx].unsqueeze(0).to(device)
label = labels[indx].item()

# 3. Generate the Grad-CAM heatmap
grayscale_cam = cam(input_tensor=input_tensor, targets=None)
grayscale_cam = grayscale_cam[0, :]

# 4. Prepare the image for Visualization
mean = torch.tensor(stats[0]).view(3, 1, 1)
std = torch.tensor(stats[1]).view(3, 1, 1)
rgb_img = imgs[indx] * std + mean # Denormalize
rgb_img = rgb_img.permute(1, 2, 0).numpy()
rgb_img = np.clip(rgb_img, 0, 1)

# 5. Overlay the heatmap on the image
visualization = show_cam_on_image(rgb_img, grayscale_cam, use_rgb=True)

# 6. Get the Prediction
model.eval()
with torch.no_grad():
    output = model(input_tensor)
    pred = output.argmax(1).item()

# 7. Plotting
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.title(f"Original (Class: {label})")
plt.imshow(rgb_img)
plt.axis('off')
plt.subplot(1, 2, 2)
plt.title(f"Grad-CAM (Pred: {pred})")
plt.imshow(visualization)
plt.axis('off')
plt.tight_layout()
plt.show()
